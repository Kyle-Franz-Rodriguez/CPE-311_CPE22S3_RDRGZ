# %% [markdown]
# # 1. Procedure

# %% [markdown]
# Example of gathering image using webcam

# %%
import cv2
from google.colab.patches import cv2_imshow # I modified this and replaced .imshow to _imshow since .imshow is disabled
key = cv2. waitKey(1)
webcam = cv2.VideoCapture(0)
while True:
  try:
    check, frame = webcam.read()
    print(check) #prints true as long as the webcam is running
    print(frame) #prints matrix values of each framecd
    cv2_imshow(frame)
    key = cv2.waitKey(1)
    if key == ord('s'):
      cv2.imwrite(filename='saved_img.jpg', img=frame)
      webcam.release()
      img_new = cv2.imread('saved_img.jpg', cv2.IMREAD_GRAYSCALE)
      img_new = cv2.imshow("Captured Image", img_new)
      cv2.waitKey(1650)
      cv2.destroyAllWindows()
      print("Processing image...")
      img_ = cv2.imread('saved_img.jpg', cv2.IMREAD_ANYCOLOR)
      print("Converting RGB image to grayscale...")
      gray = cv2.cvtColor(img_, cv2.COLOR_BGR2GRAY)
      print("Converted RGB image to grayscale...")
      print("Resizing image to 28x28 scale...")
      img_ = cv2.resize(gray,(28,28))
      print("Resized...")
      img_resized = cv2.imwrite(filename='saved_img-final.jpg', img=img_)
      print("Image saved!")
      break

    elif key == ord('q'):
      print("Turning off camera.")
      webcam.release()
      print("Camera off.")
      print("Program ended.")
      cv2.destroyAllWindows()
      break

  except(KeyboardInterrupt):
    print("Turning off camera.")
    webcam.release()
    print("Camera off.")
    print("Program ended.")
    cv2.destroyAllWindows()
    break

# %% [markdown]
# Example of gathering voice data using microphone

# %%
# !pip3 install sounddevice

# %%
# !pip3 install wavio

# %%
# !pip3 install scripy

# %%
# !apt-get install libportaudio2

# %%
# import required libraries
import sounddevice as sd
from scipy.io.wavfile import write
import wavio as wv

# Sampling frequency
freq = 44100

# Recording duration
duration = 5

# Start recorder with the given values
# of duration and sample frequency
recording = sd.rec(int(duration * freq), samplerate=freq, channels=2)

# Record audio for the given number of seconds
sd.wait()

# This will convert the NumPy array to an audio
# file with the given sampling frequency
write("recording0.wav", freq, recording)

# Convert the NumPy array to audio file
wv.write("recording1.wav", recording, freq, sampwidth=2)

# %% [markdown]
# Image Scraping using BeautifulSoup

# %%
from bs4 import BeautifulSoup

# %%
from requests import get

# %%
htmldata = get("https://www.google.com/").text
soup = BeautifulSoup(htmldata, 'html.parser')
for item in soup.find_all('img'):
 print(item['src'])
# Out:
# /images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png

# %% [markdown]
# Scraping a web using BeautifulSoup

# %%
url = 'https://m.imdb.com/search/title/?release_date=2017-01-01,2017-12-31&sort=num_votes,desc'
response = get(url)
print(response.text[:500])
# Out:
# <html>
# <head><title>403 Forbidden</title></head>
# <body>
# <center><h1>403 Forbidden</h1></center>
# </body>
# </html>

# %%
# Error 403 forbidden
# IMDB doesn't allow for simple scraping such as this anymore, I think
# I will just try to scan the given sample, and cite some external information about scraping some web

# %% [markdown]
# # 2. Scrape a web of your own

# %%
# I am obtaining a dataset for wikipedia
# It is about a list of criminals that planned to escape by a helicopter
from bs4 import BeautifulSoup
import requests
url = requests.get('https://en.wikipedia.org/wiki/List_of_helicopter_prison_escapes')
parsed = BeautifulSoup(url.text, 'html')

# %%
# Extraction the needed elements to make the dataframe
table = parsed.find_all('table')[1]

# %%
# Taking the header and the rows of the needed table
headers = table.find_all('th')
rows = table.find_all('tr')

# %%
# Making the dataframe
import pandas as pd

# %%
# Transform the headers text into a list
# Then make it as an index of the dataframe
escape_helicopter = pd.DataFrame(columns = [col.text.strip() for col in headers])

# %%
# Add the rows into the dataframe
# I will add each data of the row one by one by looping
for row in rows[1:]:
  datlist = [r.text.strip() for r in row.find_all('td')]
  escape_helicopter.loc[len(escape_helicopter)] = datlist

# %%
escape_helicopter.head()
# Out:
#                 Date                                   Prison name  \
# 0    August 19, 1971                         Santa Martha Acatitla
# 1   October 31, 1973                         Mountjoy Jail, Dublin
# 2       May 24, 1978  United States Penitentiary, Marion, Illinois
# 3  February 27, 1981        Fleury-Mérogis, Essonne, Ile de France
# 4        May 7, 1981               Orsainville Prison, Quebec City
#
#          Country Succeeded                                         Escapee(s)  \
# 0         Mexico       Yes  Joel David Kaplan\nCarlos Antonio Contreras Ca...
# 1        Ireland       Yes                JB O'HaganSeamus TwomeyKevin Mallon
# 2  United States        No  Garrett Brock TrapnellMartin Joseph McNallyJam...
# 3         France       Yes                        Gérard DupréDaniel Beaumont
# 4         Canada        No  Marina Paquet (hijacker)Giles Arseneault (pris...
#
#                                              Details
# 0  Kaplan was a New York businessman who had been...
# 1  An IRA member hijacked a helicopter and forced...
# 2  43-year-old Barbara Ann Oswald hijacked a Sain...
# 3  With the help of Serge Coutel, Dupré and Beaum...
# 4  Paquet held a sawed-off shotgun against the ba...

# %%
# Cleaning
escape_helicopter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         50 non-null     object
#  1   Prison name  50 non-null     object
#  2   Country      50 non-null     object
#  3   Succeeded    50 non-null     object
#  4   Escapee(s)   50 non-null     object
#  5   Details      50 non-null     object
# dtypes: object(6)
# memory usage: 2.7+ KB

# %%
# Make date a proper datetime
escape_helicopter.Date = pd.to_datetime(escape_helicopter.Date)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-8f9bdea78ec2> in <cell line: 0>()
#       1 # Make date a proper datetime
# ----> 2 escape_helicopter.Date = pd.to_datetime(escape_helicopter.Date)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065             result = arg.map(cache_array)
#    1066         else:
# -> 1067             values = convert_listlike(arg._values, format)
#    1068             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431     # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432     if format is not None and format != "mixed":
# --> 433         return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     434
#     435     result, tz_parsed = objects_to_datetime64(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# strptime.pyx in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "January, 1983" doesn't match format "%B %d, %Y", at position 5. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
# Noticed an error in the formatting of the dates
# I will specify the format to mixed
escape_helicopter.Date = pd.to_datetime(escape_helicopter.Date, format = 'mixed')

# %%
escape_helicopter.head()
# Out:
#         Date                                   Prison name        Country  \
# 0 1971-08-19                         Santa Martha Acatitla         Mexico
# 1 1973-10-31                         Mountjoy Jail, Dublin        Ireland
# 2 1978-05-24  United States Penitentiary, Marion, Illinois  United States
# 3 1981-02-27        Fleury-Mérogis, Essonne, Ile de France         France
# 4 1981-05-07               Orsainville Prison, Quebec City         Canada
#
#   Succeeded                                         Escapee(s)  \
# 0       Yes  Joel David Kaplan\nCarlos Antonio Contreras Ca...
# 1       Yes                JB O'HaganSeamus TwomeyKevin Mallon
# 2        No  Garrett Brock TrapnellMartin Joseph McNallyJam...
# 3       Yes                        Gérard DupréDaniel Beaumont
# 4        No  Marina Paquet (hijacker)Giles Arseneault (pris...
#
#                                              Details
# 0  Kaplan was a New York businessman who had been...
# 1  An IRA member hijacked a helicopter and forced...
# 2  43-year-old Barbara Ann Oswald hijacked a Sain...
# 3  With the help of Serge Coutel, Dupré and Beaum...
# 4  Paquet held a sawed-off shotgun against the ba...

# %%
escape_helicopter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         50 non-null     datetime64[ns]
#  1   Prison name  50 non-null     object
#  2   Country      50 non-null     object
#  3   Succeeded    50 non-null     object
#  4   Escapee(s)   50 non-null     object
#  5   Details      50 non-null     object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 2.7+ KB

# %%
# Check for duplicates
escape_helicopter.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Rename the columns to lowercases only and remove 2 worded colums
# For convenience
escape_helicopter.rename(columns = (lambda x: x.lower().split()[0]), inplace = True)

# %%
escape_helicopter.columns
# Out:
# Index(['date', 'prison', 'country', 'succeeded', 'escapee(s)', 'details'], dtype='object')

# %%
escape_helicopter.head()
# Out:
#         date                                        prison        country  \
# 0 1971-08-19                         Santa Martha Acatitla         Mexico
# 1 1973-10-31                         Mountjoy Jail, Dublin        Ireland
# 2 1978-05-24  United States Penitentiary, Marion, Illinois  United States
# 3 1981-02-27        Fleury-Mérogis, Essonne, Ile de France         France
# 4 1981-05-07               Orsainville Prison, Quebec City         Canada
#
#   succeeded                                         escapee(s)  \
# 0       Yes  Joel David Kaplan\nCarlos Antonio Contreras Ca...
# 1       Yes                JB O'HaganSeamus TwomeyKevin Mallon
# 2        No  Garrett Brock TrapnellMartin Joseph McNallyJam...
# 3       Yes                        Gérard DupréDaniel Beaumont
# 4        No  Marina Paquet (hijacker)Giles Arseneault (pris...
#
#                                              details
# 0  Kaplan was a New York businessman who had been...
# 1  An IRA member hijacked a helicopter and forced...
# 2  43-year-old Barbara Ann Oswald hijacked a Sain...
# 3  With the help of Serge Coutel, Dupré and Beaum...
# 4  Paquet held a sawed-off shotgun against the ba...

# %%
# Maybe it is more appropriate to remove the details
escape_helicopter.drop(columns = 'details', inplace = True)

# %%
escape_helicopter.columns
# Out:
# Index(['date', 'prison', 'country', 'succeeded', 'escapee(s)'], dtype='object')

# %%
escape_helicopter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        50 non-null     datetime64[ns]
#  1   prison      50 non-null     object
#  2   country     50 non-null     object
#  3   succeeded   50 non-null     object
#  4   escapee(s)  50 non-null     object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 2.3+ KB

# %%
# Check the whole transformed dataset
escape_helicopter
# Out:
#          date                                             prison  \
# 0  1971-08-19                              Santa Martha Acatitla
# 1  1973-10-31                              Mountjoy Jail, Dublin
# 2  1978-05-24       United States Penitentiary, Marion, Illinois
# 3  1981-02-27             Fleury-Mérogis, Essonne, Ile de France
# 4  1981-05-07                    Orsainville Prison, Quebec City
# 5  1983-01-01                              Pentridge (HM Prison)
# 6  1985-12-19  Perry Correctional Institution, Pelzer, South ...
# 7  1985-12-31  Cândido Mendes penitentiary, Ilha Grande, Rio ...
# 8  1986-05-26                                 Prison de la Santé
# 9  1986-11-05  Federal Correctional Institution, Dublin, Cali...
# 10 1986-11-23                         Prigione di Rebibbia, Rome
# 11 1987-12-10                                Gartree (HM Prison)
# 12 1988-07-11                         Penitentiary of New Mexico
# 13 1988-08-02                 Cárcel Bellavista, Bello, Colombia
# 14 1988-12-23                 Cárcel Bellavista, Bello, Colombia
# 15 1989-04-17           Federal Holding Facility, Miami, Florida
# 16 1989-08-19    Arkansas Valley Correctional Facility, Colorado
# 17 1990-06-19                Kent Penitentiary, British Columbia
# 18 1991-04-07        Rio Piedras State Penitentiary, Puerto Rico
# 19 1992-02-24                                        Lyon Prison
# 20 1992-12-01                     Touraine Central Prison, Tours
# 21 1993-06-17                     Touraine Central Prison, Tours
# 22 1996-12-30                     High Security Prison, Santiago
# 23 1997-09-18                                De Geerhorst prison
# 24 1999-03-25           Metropolitan Remand and Reception Centre
# 25 2000-06-05  Martin Treatment Center for Sexually Violent P...
# 26 2000-12-13                                        Lyon prison
# 27 2001-01-19                                      Luynes prison
# 28 2001-03-24                                  Draguignan prison
# 29 2001-05-28                                     Fresnes prison
# 30 2002-01-17                           Parada Neto Penitentiary
# 31 2002-12-30            Las Cucharas prison, Ponce, Puerto Rico
# 32 2003-04-04                                      Luynes prison
# 33 2005-07-01                                             France
# 34 2005-12-10                                       Aiton Prison
# 35 2006-06-06                                  Korydallos Prison
# 36 2007-04-15                               Lantin Prison, Liège
# 37 2007-07-15                                      Grasse prison
# 38 2007-10-28                                       Ittre prison
# 39 2009-02-22                                  Korydallos Prison
# 40 2009-04-27                           Domenjod Prison, Réunion
# 41 2009-07-23                                             Bruges
# 42 2010-06-25             HM Prison Isle of Wight, Isle of Wight
# 43 2012-03-22                          Sheksna, Penal colony N17
# 44 2013-02-24                            Trikala Prison, Trikala
# 45 2013-03-17            Saint-Jérôme Detention Facility, Quebec
# 46 2014-06-07             Orsainville Detention Facility, Quebec
# 47 2016-02-22                                              Thiva
# 48 2018-07-01                                   Réau, near Paris
# 49 2020-09-25                            Forest prison, Brussels
#
#            country succeeded  \
# 0           Mexico       Yes
# 1          Ireland       Yes
# 2    United States        No
# 3           France       Yes
# 4           Canada        No
# 5        Australia        No
# 6    United States       Yes
# 7           Brazil       Yes
# 8           France       Yes
# 9    United States       Yes
# 10           Italy       Yes
# 11  United Kingdom       Yes
# 12   United States       Yes
# 13        Colombia       Yes
# 14        Colombia       Yes
# 15   United States        No
# 16   United States       Yes
# 17          Canada       Yes
# 18     Puerto Rico       Yes
# 19          France       Yes
# 20          France        No
# 21          France        No
# 22           Chile       Yes
# 23     Netherlands        No
# 24       Australia       Yes
# 25   United States       Yes
# 26          France       Yes
# 27          France       Yes
# 28          France       Yes
# 29          France        No
# 30          Brazil       Yes
# 31   United States       Yes
# 32          France       Yes
# 33          France        No
# 34          France       Yes
# 35          Greece       Yes
# 36         Belgium       Yes
# 37          France       Yes
# 38         Belgium        No
# 39          Greece       Yes
# 40          France       Yes
# 41         Belgium       Yes
# 42  United Kingdom        No
# 43          Russia       Yes
# 44          Greece        No
# 45          Canada       Yes
# 46          Canada       Yes
# 47          Greece        No
# 48          France       Yes
# 49         Belgium        No
#
#                                            escapee(s)
# 0   Joel David Kaplan\nCarlos Antonio Contreras Ca...
# 1                 JB O'HaganSeamus TwomeyKevin Mallon
# 2   Garrett Brock TrapnellMartin Joseph McNallyJam...
# 3                         Gérard DupréDaniel Beaumont
# 4   Marina Paquet (hijacker)Giles Arseneault (pris...
# 5                                      David McMillan
# 6   James Rodney LeonardWilliam Douglas BallewJess...
# 7     José Carlos dos Reis Encina, a.k.a. "Escadinha"
# 8                                      Michel Vaujour
# 9                                      Samantha Lopez
# 10  André BellaïcheGianluigi EspositoLuciano Cipol...
# 11                          Sydney DraperJohn Kendall
# 12          Danny MahoneyFrancis MitchellRandy Lackey
# 13                         Dandeny MuñozBrances Muñoz
# 14                                                  —
# 15                                         Ben Kramer
# 16                        Ralph BrownFreddie Gonzales
# 17                            Robert FordDavid Thomas
# 18                                       William Lane
# 19                                                  —
# 20                                                  —
# 21                                     Michel Vaujour
# 22  Four members of the Manuel Rodriguez Patriotic...
# 23                                                  —
# 24                                       John Killick
# 25                                    Steven Whitsett
# 26                                                  —
# 27                                       Pascal Payet
# 28  Abdelhamid CarnousEmile Forma-SariJean-Philipp...
# 29                                                  —
# 30                                                  —
# 31  Orlando Cartagena Jose Rodriguez Victor Diaz H...
# 32           Eric AlboreoFranck PerlettoMichel Valero
# 33                                                  —
# 34    Hubert SellesJean-Claude MorettiMohamed Bessame
# 35                    Vassilis PaleokostasAlket Rizai
# 36                                     Eric Ferdinand
# 37                                       Pascal Payet
# 38                                    Nordin Benallal
# 39                     Vasilis PaleokostasAlket Rizai
# 40          Juliano VerbardAlexin JismyFabrice Michel
# 41          Ashraf Sekkaki plus three other criminals
# 42                                     Brian Lawrence
# 43                                   Alexey Shestakov
# 44                                 Panagiotis Vlastos
# 45              Benjamin Hudon-BarbeauDanny Provençal
# 46            Yves DenisDenis LefebvreSerge Pomerleau
# 47                           Pola RoupaNikos Maziotis
# 48                                       Rédoine Faïd
# 49                                         Kristel A.

# %%
# Save the dataframe to csv file
escape_helicopter.to_csv('helicopter_prison_escape.csv', index = False)

# %%
# Load the csv to check
df = pd.read_csv('helicopter_prison_escape.csv')

# %%
df.head()
# Out:
#          date                                        prison        country  \
# 0  1971-08-19                         Santa Martha Acatitla         Mexico
# 1  1973-10-31                         Mountjoy Jail, Dublin        Ireland
# 2  1978-05-24  United States Penitentiary, Marion, Illinois  United States
# 3  1981-02-27        Fleury-Mérogis, Essonne, Ile de France         France
# 4  1981-05-07               Orsainville Prison, Quebec City         Canada
#
#   succeeded                                         escapee(s)
# 0       Yes  Joel David Kaplan\nCarlos Antonio Contreras Ca...
# 1       Yes                JB O'HaganSeamus TwomeyKevin Mallon
# 2        No  Garrett Brock TrapnellMartin Joseph McNallyJam...
# 3       Yes                        Gérard DupréDaniel Beaumont
# 4        No  Marina Paquet (hijacker)Giles Arseneault (pris...
